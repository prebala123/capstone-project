# %%
import numpy as np
import json
import gzip
from scipy.sparse import coo_matrix
from scipy.stats import binned_statistic_2d
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import pandas as pd
from collections import defaultdict

# %%
raw_data_dir = '../../data/chips/NCSU-DigIC-GraphData-2023-07-25/'
data_dir = '../../data/chips/clean_data/'
design = 'xbar'
N = 13

sample_names = []
corresponding_design = []
corresponding_variant = []
for idx in range(N):
    sample_name = raw_data_dir + design + '/' + str(idx + 1) + '/'
    sample_names.append(sample_name)
    corresponding_design.append(design)
    corresponding_variant.append(idx + 1)

# %% [markdown]
# # Global Information

# %%
with open(raw_data_dir + 'settings.csv') as f:
    lines = f.readlines()

lines = lines[1:]
for line in lines:
    words = line.strip().split(',')
    dictionary = {
        'design': words[0],
        'variant': int(words[1]),
        'core_utilization': float(words[2]),
        'max_routing_layer': words[3],
        'clk_per': int(words[4]),
        'clk_uncertainty': float(words[5]),
        'flow_stage': words[6],
        'hstrap_layer': words[7],
        'hstrap_width': float(words[8]),
        'hstrap_pitch': float(words[9]),
        'vstrap_layer': words[10],
        'vstrap_width': float(words[11]),
        'vstrap_pitch': float(words[12])
    }

    if dictionary['design'] != design:
        continue

    sample_idx = -1
    for idx in range(N):
        if dictionary['design'] == corresponding_design[idx] and dictionary['variant'] == corresponding_variant[idx]:
            sample_idx = idx
            break

    fn = data_dir + str(sample_idx) + '.global_information.pkl'
    f = open(fn, "wb")
    pickle.dump(dictionary, f)
    f.close()
    print('Save file', fn)
# Out:
# Save file ../../data/chips/clean_data/0.global_information.pkl
# Save file ../../data/chips/clean_data/1.global_information.pkl
# Save file ../../data/chips/clean_data/2.global_information.pkl
# Save file ../../data/chips/clean_data/3.global_information.pkl
# Save file ../../data/chips/clean_data/4.global_information.pkl
# Save file ../../data/chips/clean_data/5.global_information.pkl
# Save file ../../data/chips/clean_data/6.global_information.pkl
# Save file ../../data/chips/clean_data/7.global_information.pkl
# Save file ../../data/chips/clean_data/8.global_information.pkl
# Save file ../../data/chips/clean_data/9.global_information.pkl
# Save file ../../data/chips/clean_data/10.global_information.pkl
# Save file ../../data/chips/clean_data/11.global_information.pkl
# Save file ../../data/chips/clean_data/12.global_information.pkl

# %% [markdown]
# # Cell Information

# %%
cells_fn = raw_data_dir + 'cells.json.gz'
with gzip.open(cells_fn, 'r') as fin:
    cell_data = json.load(fin)

widths = []
heights = []
for idx in range(len(cell_data)):
    width = cell_data[idx]['width']
    height = cell_data[idx]['height']
    widths.append(width)
    heights.append(height)

widths = np.array(widths)
heights = np.array(heights)

min_cell_width = np.min(widths)
max_cell_width = np.max(widths)
min_cell_height = np.min(heights)
max_cell_height = np.max(heights)

print('min cell width:', min_cell_width)
print('max cell width:', max_cell_width)
print('mean cell width:', np.mean(widths))
print('std cell width:', np.std(widths))
print()
print('min cell height:', min_cell_height)
print('max cell height:', max_cell_height)
print('mean cell height:', np.mean(heights))
print('std cell height:', np.std(heights))

widths = (widths - min_cell_width) / (max_cell_width - min_cell_width)
heights = (heights - min_cell_height) / (max_cell_height - min_cell_height)
print('Done processing cell sizes')

cell_to_edge_dict = {item['id']:{inner_item['id']: inner_item['dir'] for inner_item in item['terms']} for item in cell_data}
print('Done processing edge types dict')
# Out:
# min cell width: 256
# max cell width: 397440
# mean cell width: 14540.25
# std cell width: 63888.21937522989
#
# min cell height: 1536
# max cell height: 503056
# mean cell height: 16009.0
# std cell height: 68982.92421027106
# Done processing cell sizes
# Done processing edge types dict

# %% [markdown]
# # Instances and Nets

# %%
for sample in range(N):
    
    # +--------------------------------------+
    # | Information about instances and nets |
    # +--------------------------------------+

    folder = sample_names[sample]
    design = corresponding_design[sample]
    instances_nets_fn = folder + design + '.json.gz'

    print('--------------------------------------------------')
    print('Folder:', folder)
    print('Design:', design)
    print('Instances & nets info:', instances_nets_fn)

    with gzip.open(instances_nets_fn, 'r') as fin:
        instances_nets_data = json.load(fin)

    instances = instances_nets_data['instances']
    nets = instances_nets_data['nets']

    inst_to_cell = {item['id']:item['cell'] for item in instances}

    num_instances = len(instances)
    num_nets = len(nets)

    print('Number of instances:', num_instances)
    print('Number of nets:', num_nets)

    xloc_list = [instances[idx]['xloc'] for idx in range(num_instances)]
    yloc_list = [instances[idx]['yloc'] for idx in range(num_instances)]
    cell = [instances[idx]['cell'] for idx in range(num_instances)]
    cell_width = [widths[cell[idx]] for idx in range(num_instances)]
    cell_height = [heights[cell[idx]] for idx in range(num_instances)]
    orient = [instances[idx]['orient'] for idx in range(num_instances)]
    
    x_min = min(xloc_list)
    x_max = max(xloc_list)
    y_min = min(yloc_list)
    y_max = max(yloc_list)

    print('min xloc:', x_min)
    print('max xloc:', x_max)
    print('min yloc:', y_min)
    print('max yloc:', y_max)

    X = np.expand_dims(np.array(xloc_list), axis = 1)
    Y = np.expand_dims(np.array(yloc_list), axis = 1)
    X = (X - x_min) / (x_max - x_min)
    Y = (Y - y_min) / (y_max - y_min)

    cell = np.expand_dims(np.array(cell), axis = 1)
    cell_width = np.expand_dims(np.array(cell_width), axis = 1)
    cell_height = np.expand_dims(np.array(cell_height), axis = 1)
    orient = np.expand_dims(np.array(orient), axis = 1)

    instance_features = np.concatenate((X, Y, cell, cell_width, cell_height, orient), axis = 1)

    dictionary = {
        'num_instances': num_instances,
        'num_nets': num_nets,
        'x_min': x_min,
        'x_max': x_max,
        'y_min': y_min,
        'y_max': y_max,
        'min_cell_width': min_cell_width,
        'max_cell_width': max_cell_width,
        'min_cell_height': min_cell_height,
        'max_cell_height': max_cell_height,
        'instance_features': instance_features,
        'sample_name': sample_name,
        'folder': folder,
        'design': design
    }
    fn = data_dir + '/' + str(sample) + '.node_features.pkl'
    f = open(fn, "wb")
    pickle.dump(dictionary, f)
    f.close()
    print('Save file', fn)

    connection_fn = folder + design + '_connectivity.npz'
    connection_data = np.load(connection_fn)
    print('Connection info:', connection_fn)
    
    # get the direction of each edge between inst and net
    dirs = []
    edge_t = connection_data['data']
    instance_idx = connection_data['row']
    
    for idx in range(len(instance_idx)):
        inst = instance_idx[idx]
        cell = inst_to_cell[inst]
        edge_dict = cell_to_edge_dict[cell]
        t = edge_t[idx]
        direction = edge_dict[t]
        dirs.append(direction)

    dirs = np.array(dirs)
    
    assert dirs.shape == connection_data['data'].shape
    
    dictionary = {
        'instance_idx': connection_data['row'],
        'net_idx': connection_data['col'],
        'edge_attr': connection_data['data'],
        'edge_dir': dirs, 
        'sample_name': sample_name,
        'folder': folder,
        'design': design
    }
    
    edge_index = np.array([dictionary['instance_idx'], dictionary['net_idx']]).T
    edge_dir = dictionary['edge_dir']
    n_edge_index = []
    for idx in range(len(edge_index)):
        tp = edge_index[idx]
        direct = edge_dir[idx]

        if direct == 0:
            n_edge_index.append([tp[1], tp[0]])
        else:
            n_edge_index.append([tp[0], tp[1]])

    n_edge_index = np.array(n_edge_index).T
   
    dictionary['edge_index'] = n_edge_index

    
    fn = data_dir + '/' + str(sample) + '.bipartite.pkl'
    f = open(fn, "wb")
    pickle.dump(dictionary, f)
    f.close()
    print('Save file', fn)

    instances = dictionary['instance_idx']
    nets = dictionary['net_idx']
    directs = dictionary['edge_dir']
    attrs = dictionary['edge_attr']
    
    drive_dict = dict()
    for idx in range(len(instances)):
        direct = directs[idx]
        net = nets[idx]

        if direct == 1:
            assert net not in drive_dict

            drive_dict[net] = idx
        else:
            continue

    print("finished building drive and net dict")

    n_row = []
    n_col = []
    n_edge_attr = []
    b_nets = []
    b_terms = []
    for idx in range(len(nets)):
        net = nets[idx]
        inst = instances[idx]
        attr = attrs[idx]
        
        if net not in drive_dict:
            b_nets.append(net)
            b_terms.append(idx)
        else:
            inst_idx = drive_dict[net]
            drive_inst = instances[inst_idx]
            
            if inst == drive_inst:
                continue
                
            n_row.append(drive_inst)
            n_col.append(inst)
            n_edge_attr.append(attr)
    
    
    #dictionary['edge_attr'] = np.array(n_edge_attr)
    edge_index = np.array([n_row, n_col]).T
    dictionary['edge_index'] = edge_index
    dictionary['b_nets'] = b_nets
    dictionary['b_terms'] = b_terms
    
    
    
    pos_lst = instance_features[:, :2] 
    for idx in range(len(edge_index)):
        tp = edge_index[idx]
        direct = edge_dir[idx]

        # compute the edge distances based on nodes' positions
        first_pos = pos_lst[tp[0]]
        second_pos = pos_lst[tp[1]]
        l1_dis = np.linalg.norm((first_pos - second_pos), ord=1)
        new_attr = [l1_dis]
        if idx == 0:
            print(new_attr)
        n_edge_attr[idx] = new_attr
    

    n_edge_attr = np.array(n_edge_attr)
    print(n_edge_attr.shape, n_edge_attr[-1])
    dictionary['edge_attr'] = n_edge_attr
    

    fn = data_dir + '/' + str(sample) + '.star.pkl'
    f = open(fn, "wb")
    pickle.dump(dictionary, f)
    f.close()
    print('Save file', fn)

    congestion_fn = folder + design + '_congestion.npz'
    congestion_data = np.load(congestion_fn)
    print('Congestion info:', congestion_fn)

    congestion_data_demand = congestion_data['demand']
    congestion_data_capacity = congestion_data['capacity']

    num_layers = len(list(congestion_data['layerList']))
    print('Number of layers:', num_layers)
    print('Layers:', list(congestion_data['layerList']))

    ybl = congestion_data['yBoundaryList']
    xbl = congestion_data['xBoundaryList']

    all_demand = []
    all_capacity = []

    for layer in list(congestion_data['layerList']):
        print('Layer', layer, ':')
        lyr = list(congestion_data['layerList']).index(layer)

        # Binned statistics 2D
        t = time.time()
        ret = binned_statistic_2d(xloc_list, yloc_list, None, 'count', bins = [xbl[1:], ybl[1:]], expand_binnumbers = True)
        print('Time for binned statistics:', time.time() - t)

        i_list = np.array([ret.binnumber[0, idx] - 1 for idx in range(num_instances)])
        j_list = np.array([ret.binnumber[1, idx] - 1 for idx in range(num_instances)])

        # Get demand and capacity
        t = time.time()
        demand_list = congestion_data_demand[lyr, i_list, j_list].flatten()
        capacity_list = congestion_data_capacity[lyr, i_list, j_list].flatten()
        print('Time to get demand and capacity:', time.time() - t)

        demand_list = np.array(demand_list)
        capacity_list = np.array(capacity_list)

        all_demand.append(np.expand_dims(demand_list, axis = 1))
        all_capacity.append(np.expand_dims(capacity_list, axis = 1))

        average_demand = np.mean(demand_list)
        average_capacity = np.mean(capacity_list)
        average_diff = np.mean(capacity_list - demand_list)
        count_congestions = np.sum(demand_list > capacity_list)

        print('    Number of demand > capacity:', count_congestions)
        print('    Average capacity - demand:', average_diff)
        print('    Average demand:', average_demand)
        print('    Average capacity:', average_capacity)

    demand = np.concatenate(all_demand, axis = 1)
    capacity = np.concatenate(all_capacity, axis = 1)

    dictionary = {
        'demand': demand,
        'capacity': capacity
    }
    fn = data_dir + '/' + str(sample) + '.targets.pkl'
    f = open(fn, "wb")
    pickle.dump(dictionary, f)
    f.close()
    print('Save file', fn)
# Out:
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/1/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/1/xbar.json.gz
# Number of instances: 3952
# Number of nets: 4482
# min xloc: 512
# max xloc: 84096
# min yloc: 1536
# max yloc: 87552
# Save file ../../data/chips/clean_data//0.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/1/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//0.bipartite.pkl
# finished building drive and net dict
# [0.1919164296652811]
# (10657, 1) [0.05819296]
# Save file ../../data/chips/clean_data//0.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/1/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0009996891021728516
# Time to get demand and capacity: 0.0015099048614501953
#     Number of demand > capacity: 4
#     Average capacity - demand: 0.013663967611336033
#     Average demand: 0.013663967611336033
#     Average capacity: 0.027327935222672066
# Layer MINT1 :
# Time for binned statistics: 0.0005230903625488281
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 3301
#     Average capacity - demand: -2.235323886639676
#     Average demand: 13.14094129554656
#     Average capacity: 10.905617408906883
# Layer MINT2 :
# Time for binned statistics: 0.0
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 3011
#     Average capacity - demand: -1.8729757085020242
#     Average demand: 11.740890688259109
#     Average capacity: 9.867914979757085
# Layer MINT3 :
# Time for binned statistics: 0.0009982585906982422
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 11.73911943319838
#     Average demand: 0.019230769230769232
#     Average capacity: 11.758350202429149
# Layer MINT4 :
# Time for binned statistics: 0.0010075569152832031
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MINT5 :
# Time for binned statistics: 0.0009996891021728516
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG1 :
# Time for binned statistics: 0.0010173320770263672
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0009987354278564453
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.0
# Time to get demand and capacity: 0.001004934310913086
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0010249614715576172
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0007987022399902344
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0009970664978027344
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//0.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/2/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/2/xbar.json.gz
# Number of instances: 6872
# Number of nets: 7404
# min xloc: 512
# max xloc: 93056
# min yloc: 1536
# max yloc: 96768
# Save file ../../data/chips/clean_data//1.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/2/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//1.bipartite.pkl
# finished building drive and net dict
# [0.03225806451612906]
# (15725, 1) [0.03457815]
# Save file ../../data/chips/clean_data//1.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/2/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0019989013671875
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.04118160651920838
#     Average demand: 0.003346915017462165
#     Average capacity: 0.04452852153667055
# Layer MINT1 :
# Time for binned statistics: 0.00099945068359375
# Time to get demand and capacity: 0.0010225772857666016
#     Number of demand > capacity: 71
#     Average capacity - demand: 4.122526193247963
#     Average demand: 7.023428405122235
#     Average capacity: 11.145954598370198
# Layer MINT2 :
# Time for binned statistics: 0.0010018348693847656
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 1781
#     Average capacity - demand: 1.1626891734575087
#     Average demand: 8.663853317811409
#     Average capacity: 9.826542491268917
# Layer MINT3 :
# Time for binned statistics: 0.0010166168212890625
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 53
#     Average capacity - demand: 4.590948777648428
#     Average demand: 7.165745052386496
#     Average capacity: 11.756693830034925
# Layer MINT4 :
# Time for binned statistics: 0.0015044212341308594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 678
#     Average capacity - demand: 2.564464493597206
#     Average demand: 7.268480791618161
#     Average capacity: 9.832945285215366
# Layer MINT5 :
# Time for binned statistics: 0.0009913444519042969
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 4
#     Average capacity - demand: 7.138387660069848
#     Average demand: 4.6276193247962745
#     Average capacity: 11.766006984866124
# Layer MSMG1 :
# Time for binned statistics: 0.000993490219116211
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 5.420110593713621
#     Average demand: 0.0
#     Average capacity: 5.420110593713621
# Layer MSMG2 :
# Time for binned statistics: 0.0009894371032714844
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0009999275207519531
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.002015829086303711
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0009975433349609375
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0009980201721191406
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.002054452896118164
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//1.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/3/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/3/xbar.json.gz
# Number of instances: 6913
# Number of nets: 7445
# min xloc: 512
# max xloc: 96512
# min yloc: 1536
# max yloc: 96768
# Save file ../../data/chips/clean_data//2.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/3/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//2.bipartite.pkl
# finished building drive and net dict
# [0.004]
# (15480, 1) [0.03333333]
# Save file ../../data/chips/clean_data//2.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/3/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0009989738464355469
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.017647909735281353
#     Average demand: 0.0014465499783017503
#     Average capacity: 0.019094459713583103
# Layer MINT1 :
# Time for binned statistics: 0.0015037059783935547
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 9
#     Average capacity - demand: 5.083176623752351
#     Average demand: 5.988427600173586
#     Average capacity: 11.071604223925936
# Layer MINT2 :
# Time for binned statistics: 0.0009987354278564453
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 635
#     Average capacity - demand: 2.2813539707796906
#     Average demand: 7.572544481411833
#     Average capacity: 9.853898452191522
# Layer MINT3 :
# Time for binned statistics: 0.0010013580322265625
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 6.633733545493997
#     Average demand: 5.114711413279329
#     Average capacity: 11.748444958773325
# Layer MINT4 :
# Time for binned statistics: 0.0005033016204833984
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 86
#     Average capacity - demand: 3.6885577896716333
#     Average demand: 6.165051352524229
#     Average capacity: 9.853609142195863
# Layer MINT5 :
# Time for binned statistics: 0.0010006427764892578
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 9.292347750614784
#     Average demand: 2.4643425430348618
#     Average capacity: 11.756690293649646
# Layer MSMG1 :
# Time for binned statistics: 0.0010039806365966797
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 5.433531028497034
#     Average demand: 0.0
#     Average capacity: 5.433531028497034
# Layer MSMG2 :
# Time for binned statistics: 0.0013265609741210938
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0015981197357177734
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.0008578300476074219
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0030126571655273438
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.00099945068359375
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0011098384857177734
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//2.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/4/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/4/xbar.json.gz
# Number of instances: 7323
# Number of nets: 7855
# min xloc: 512
# max xloc: 103040
# min yloc: 1536
# max yloc: 102912
# Save file ../../data/chips/clean_data//3.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/4/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//3.bipartite.pkl
# finished building drive and net dict
# [0.0]
# (15808, 1) [0.00374532]
# Save file ../../data/chips/clean_data//3.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/4/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0020093917846679688
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.035231462515362556
#     Average demand: 0.0021848969001775228
#     Average capacity: 0.03741635941554008
# Layer MINT1 :
# Time for binned statistics: 0.00099945068359375
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 3
#     Average capacity - demand: 5.327324866857845
#     Average demand: 5.838863853611907
#     Average capacity: 11.166188720469753
# Layer MINT2 :
# Time for binned statistics: 0.001153707504272461
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 613
#     Average capacity - demand: 2.627338522463471
#     Average demand: 7.216714461286358
#     Average capacity: 9.84405298374983
# Layer MINT3 :
# Time for binned statistics: 0.0010039806365966797
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 8
#     Average capacity - demand: 6.7655332513997
#     Average demand: 4.994401201693295
#     Average capacity: 11.759934453092995
# Layer MINT4 :
# Time for binned statistics: 0.001512289047241211
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 71
#     Average capacity - demand: 3.9175201420182986
#     Average demand: 5.931175747644408
#     Average capacity: 9.848695889662707
# Layer MINT5 :
# Time for binned statistics: 0.0009982585906982422
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 8.683872729755565
#     Average demand: 3.0811142974190906
#     Average capacity: 11.764987027174655
# Layer MSMG1 :
# Time for binned statistics: 0.0010008811950683594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 5.420456097227912
#     Average demand: 0.0012290045063498567
#     Average capacity: 5.421685101734262
# Layer MSMG2 :
# Time for binned statistics: 0.0015301704406738281
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0010080337524414062
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.001004934310913086
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0012164115905761719
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.00200653076171875
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0016210079193115234
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//3.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/5/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/5/xbar.json.gz
# Number of instances: 7258
# Number of nets: 7790
# min xloc: 512
# max xloc: 103040
# min yloc: 1536
# max yloc: 102912
# Save file ../../data/chips/clean_data//4.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/5/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//4.bipartite.pkl
# finished building drive and net dict
# [0.0]
# (15757, 1) [0.03030303]
# Save file ../../data/chips/clean_data//4.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/5/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0010790824890136719
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.032791402590245246
#     Average demand: 0.002342243042160375
#     Average capacity: 0.03513364563240562
# Layer MINT1 :
# Time for binned statistics: 0.0010800361633300781
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 21
#     Average capacity - demand: 5.474235326536236
#     Average demand: 5.718517497933315
#     Average capacity: 11.19275282446955
# Layer MINT2 :
# Time for binned statistics: 0.0005054473876953125
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 588
#     Average capacity - demand: 2.6679526040231467
#     Average demand: 7.206255166712593
#     Average capacity: 9.87420777073574
# Layer MINT3 :
# Time for binned statistics: 0.0010085105895996094
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 1
#     Average capacity - demand: 6.838523009093414
#     Average demand: 4.925599338660788
#     Average capacity: 11.764122347754203
# Layer MINT4 :
# Time for binned statistics: 0.0015115737915039062
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 73
#     Average capacity - demand: 4.137227886470102
#     Average demand: 5.740562138330119
#     Average capacity: 9.87779002480022
# Layer MINT5 :
# Time for binned statistics: 0.0010018348693847656
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 8.799807109396529
#     Average demand: 2.969413061449435
#     Average capacity: 11.769220170845964
# Layer MSMG1 :
# Time for binned statistics: 0.0009987354278564453
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 5.433728299807109
#     Average demand: 0.0012400110223201985
#     Average capacity: 5.434968310829429
# Layer MSMG2 :
# Time for binned statistics: 0.0010042190551757812
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0010073184967041016
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.0010013580322265625
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0017774105072021484
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.001999378204345703
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0009953975677490234
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//4.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/6/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/6/xbar.json.gz
# Number of instances: 7120
# Number of nets: 7652
# min xloc: 512
# max xloc: 99968
# min yloc: 1536
# max yloc: 99840
# Save file ../../data/chips/clean_data//5.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/6/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//5.bipartite.pkl
# finished building drive and net dict
# [0.03125]
# (15677, 1) [0.01029601]
# Save file ../../data/chips/clean_data//5.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/6/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0010030269622802734
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.035674157303370785
#     Average demand: 0.0018258426966292136
#     Average capacity: 0.0375
# Layer MINT1 :
# Time for binned statistics: 0.0010097026824951172
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 43
#     Average capacity - demand: 4.1035112359550565
#     Average demand: 7.017837078651685
#     Average capacity: 11.121348314606742
# Layer MINT2 :
# Time for binned statistics: 0.0015044212341308594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 804
#     Average capacity - demand: 2.075421348314607
#     Average demand: 7.747752808988764
#     Average capacity: 9.82317415730337
# Layer MINT3 :
# Time for binned statistics: 0.0010023117065429688
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 39
#     Average capacity - demand: 4.451123595505618
#     Average demand: 7.3039325842696625
#     Average capacity: 11.75505617977528
# Layer MINT4 :
# Time for binned statistics: 0.0009915828704833984
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 67
#     Average capacity - demand: 3.7839887640449437
#     Average demand: 6.043820224719101
#     Average capacity: 9.827808988764044
# Layer MINT5 :
# Time for binned statistics: 0.0020036697387695312
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 11.758005617977528
#     Average demand: 0.0035112359550561797
#     Average capacity: 11.761516853932584
# Layer MSMG1 :
# Time for binned statistics: 0.0009860992431640625
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0010242462158203125
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0010066032409667969
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.000989675521850586
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.001512765884399414
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0009982585906982422
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0009992122650146484
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//5.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/7/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/7/xbar.json.gz
# Number of instances: 7879
# Number of nets: 8411
# min xloc: 512
# max xloc: 110720
# min yloc: 1536
# max yloc: 109056
# Save file ../../data/chips/clean_data//6.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/7/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//6.bipartite.pkl
# finished building drive and net dict
# [0.0]
# (16210, 1) [0.00696864]
# Save file ../../data/chips/clean_data//6.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/7/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0019998550415039062
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 9
#     Average capacity - demand: 0.11587764944789948
#     Average demand: 0.011549689046833355
#     Average capacity: 0.12742733849473284
# Layer MINT1 :
# Time for binned statistics: 0.0009891986846923828
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 422
#     Average capacity - demand: 3.0729788044168043
#     Average demand: 7.831577611372001
#     Average capacity: 10.904556415788806
# Layer MINT2 :
# Time for binned statistics: 0.002169370651245117
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 5918
#     Average capacity - demand: -1.7050387104962559
#     Average demand: 11.51948216778779
#     Average capacity: 9.814443457291535
# Layer MINT3 :
# Time for binned statistics: 0.000997304916381836
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 399
#     Average capacity - demand: 3.726741972331514
#     Average demand: 8.023480137073232
#     Average capacity: 11.750222109404747
# Layer MINT4 :
# Time for binned statistics: 0.0010344982147216797
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 9.788678766340906
#     Average demand: 0.04289884503109532
#     Average capacity: 9.831577611372001
# Layer MINT5 :
# Time for binned statistics: 0.0019981861114501953
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG1 :
# Time for binned statistics: 0.0019996166229248047
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0020101070404052734
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0010001659393310547
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.0010061264038085938
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0009996891021728516
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0009932518005371094
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.001007080078125
# Time to get demand and capacity: 0.0010008811950683594
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//6.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/8/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/8/xbar.json.gz
# Number of instances: 7626
# Number of nets: 8158
# min xloc: 512
# max xloc: 114048
# min yloc: 1536
# max yloc: 112128
# Save file ../../data/chips/clean_data//7.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/8/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//7.bipartite.pkl
# finished building drive and net dict
# [0.02890517349367407]
# (16416, 1) [0.00901917]
# Save file ../../data/chips/clean_data//7.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/8/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0020465850830078125
# Time to get demand and capacity: 0.00099945068359375
#     Number of demand > capacity: 6
#     Average capacity - demand: 0.04274849200104904
#     Average demand: 0.01035929714135851
#     Average capacity: 0.053107789142407553
# Layer MINT1 :
# Time for binned statistics: 0.001999378204345703
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 241
#     Average capacity - demand: 3.598085496984002
#     Average demand: 7.459349593495935
#     Average capacity: 11.057435090479936
# Layer MINT2 :
# Time for binned statistics: 0.0010013580322265625
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 5108
#     Average capacity - demand: -0.9445318646734855
#     Average demand: 10.800157356412274
#     Average capacity: 9.855625491738788
# Layer MINT3 :
# Time for binned statistics: 0.0009953975677490234
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 202
#     Average capacity - demand: 4.841987936008392
#     Average demand: 6.914109624967217
#     Average capacity: 11.75609756097561
# Layer MINT4 :
# Time for binned statistics: 0.0010008811950683594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 9.81904012588513
#     Average demand: 0.04353527406241804
#     Average capacity: 9.862575399947549
# Layer MINT5 :
# Time for binned statistics: 0.001734018325805664
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG1 :
# Time for binned statistics: 0.0009937286376953125
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0009968280792236328
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0018799304962158203
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.002009153366088867
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0017616748809814453
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0010073184967041016
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0020220279693603516
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//7.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/9/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/9/xbar.json.gz
# Number of instances: 7620
# Number of nets: 8153
# min xloc: 512
# max xloc: 107008
# min yloc: 1536
# max yloc: 105984
# Save file ../../data/chips/clean_data//8.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/9/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//8.bipartite.pkl
# finished building drive and net dict
# [0.036057692307692304]
# (15968, 1) [0.00360577]
# Save file ../../data/chips/clean_data//8.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/9/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0020112991333007812
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.1269028871391076
#     Average demand: 0.0028871391076115485
#     Average capacity: 0.12979002624671915
# Layer MINT1 :
# Time for binned statistics: 0.0009989738464355469
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 32
#     Average capacity - demand: 4.551574803149606
#     Average demand: 6.3715223097112865
#     Average capacity: 10.923097112860892
# Layer MINT2 :
# Time for binned statistics: 0.0026471614837646484
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 1146
#     Average capacity - demand: 2.323490813648294
#     Average demand: 7.459317585301838
#     Average capacity: 9.78280839895013
# Layer MINT3 :
# Time for binned statistics: 0.0016598701477050781
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 14
#     Average capacity - demand: 5.669685039370079
#     Average demand: 6.072965879265092
#     Average capacity: 11.74265091863517
# Layer MINT4 :
# Time for binned statistics: 0.0016064643859863281
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 142
#     Average capacity - demand: 4.002230971128609
#     Average demand: 5.794488188976378
#     Average capacity: 9.796719160104987
# Layer MINT5 :
# Time for binned statistics: 0.0011601448059082031
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 11.751049868766405
#     Average demand: 0.0
#     Average capacity: 11.751049868766405
# Layer MSMG1 :
# Time for binned statistics: 0.0008943080902099609
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0016796588897705078
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0009915828704833984
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.001007080078125
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.00099945068359375
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0010027885437011719
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0020012855529785156
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//8.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/10/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/10/xbar.json.gz
# Number of instances: 7772
# Number of nets: 8304
# min xloc: 512
# max xloc: 109952
# min yloc: 1536
# max yloc: 109056
# Save file ../../data/chips/clean_data//9.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/10/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//9.bipartite.pkl
# finished building drive and net dict
# [0.02857142857142858]
# (16309, 1) [0.00116959]
# Save file ../../data/chips/clean_data//9.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/10/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0021119117736816406
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.058414822439526504
#     Average demand: 0.003988677303139475
#     Average capacity: 0.06240349974266598
# Layer MINT1 :
# Time for binned statistics: 0.0010035037994384766
# Time to get demand and capacity: 0.0009944438934326172
#     Number of demand > capacity: 33
#     Average capacity - demand: 5.237647967061245
#     Average demand: 5.760550694801853
#     Average capacity: 10.998198661863098
# Layer MINT2 :
# Time for binned statistics: 0.0015232563018798828
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 420
#     Average capacity - demand: 2.9813432835820897
#     Average demand: 6.946345856922285
#     Average capacity: 9.927689140504375
# Layer MINT3 :
# Time for binned statistics: 0.0020296573638916016
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 13
#     Average capacity - demand: 6.122104992279979
#     Average demand: 5.643721049922799
#     Average capacity: 11.765826042202779
# Layer MINT4 :
# Time for binned statistics: 0.0019843578338623047
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 38
#     Average capacity - demand: 4.628152341739578
#     Average demand: 5.305326814204838
#     Average capacity: 9.933479155944417
# Layer MINT5 :
# Time for binned statistics: 0.0020182132720947266
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 11.769428718476583
#     Average demand: 0.0014153371075656203
#     Average capacity: 11.770844055584147
# Layer MSMG1 :
# Time for binned statistics: 0.0010080337524414062
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.002016305923461914
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0009906291961669922
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.002003908157348633
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0024199485778808594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0020017623901367188
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0015044212341308594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//9.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/11/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/11/xbar.json.gz
# Number of instances: 7814
# Number of nets: 8346
# min xloc: 512
# max xloc: 109952
# min yloc: 1536
# max yloc: 109056
# Save file ../../data/chips/clean_data//10.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/11/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//10.bipartite.pkl
# finished building drive and net dict
# [0.030910609857978288]
# (16544, 1) [0.00701754]
# Save file ../../data/chips/clean_data//10.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/11/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.002009868621826172
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 3
#     Average capacity - demand: 0.02905042231891477
#     Average demand: 0.009342206296391093
#     Average capacity: 0.03839262861530586
# Layer MINT1 :
# Time for binned statistics: 0.0015094280242919922
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 414
#     Average capacity - demand: 3.1196570258510365
#     Average demand: 7.872152546711032
#     Average capacity: 10.991809572562069
# Layer MINT2 :
# Time for binned statistics: 0.0015065670013427734
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 5741
#     Average capacity - demand: -1.5303301766060917
#     Average demand: 11.432556949065779
#     Average capacity: 9.902226772459688
# Layer MINT3 :
# Time for binned statistics: 0.0019986629486083984
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 209
#     Average capacity - demand: 4.083184028666496
#     Average demand: 7.677373944202713
#     Average capacity: 11.76055797286921
# Layer MINT4 :
# Time for binned statistics: 0.0010540485382080078
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 9.82518556437164
#     Average demand: 0.0815203480931661
#     Average capacity: 9.906705912464806
# Layer MINT5 :
# Time for binned statistics: 0.0020051002502441406
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG1 :
# Time for binned statistics: 0.0010094642639160156
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0007398128509521484
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0009963512420654297
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.0019371509552001953
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.002994060516357422
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0020055770874023438
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0010008811950683594
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//10.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/12/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/12/xbar.json.gz
# Number of instances: 6529
# Number of nets: 7061
# min xloc: 512
# max xloc: 96640
# min yloc: 1536
# max yloc: 96768
# Save file ../../data/chips/clean_data//11.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/12/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//11.bipartite.pkl
# finished building drive and net dict
# [0.0985352862849534]
# (15401, 1) [0.0938104]
# Save file ../../data/chips/clean_data//11.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/12/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.002000570297241211
# Time to get demand and capacity: 0.0010006427764892578
#     Number of demand > capacity: 9
#     Average capacity - demand: 0.02649716648797672
#     Average demand: 0.01102772246898453
#     Average capacity: 0.03752488895696125
# Layer MINT1 :
# Time for binned statistics: 0.00200653076171875
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 591
#     Average capacity - demand: 2.371419819267882
#     Average demand: 8.47342625210599
#     Average capacity: 10.84484607137387
# Layer MINT2 :
# Time for binned statistics: 0.0009999275207519531
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 5273
#     Average capacity - demand: -2.2658906417521827
#     Average demand: 12.126818808393322
#     Average capacity: 9.86092816664114
# Layer MINT3 :
# Time for binned statistics: 0.0009899139404296875
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 646
#     Average capacity - demand: 2.8183489048858936
#     Average demand: 8.929391943636086
#     Average capacity: 11.747740848521978
# Layer MINT4 :
# Time for binned statistics: 0.0005118846893310547
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 9.792770715270333
#     Average demand: 0.0698422423035687
#     Average capacity: 9.862612957573901
# Layer MINT5 :
# Time for binned statistics: 0.001007080078125
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG1 :
# Time for binned statistics: 0.0010094642639160156
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.0019986629486083984
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.0009982585906982422
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.0010097026824951172
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0009996891021728516
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.0010838508605957031
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0009975433349609375
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//11.targets.pkl
# --------------------------------------------------
# Folder: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/13/
# Design: xbar
# Instances & nets info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/13/xbar.json.gz
# Number of instances: 6548
# Number of nets: 7082
# min xloc: 512
# max xloc: 94080
# min yloc: 1536
# max yloc: 93696
# Save file ../../data/chips/clean_data//12.node_features.pkl
# Connection info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/13/xbar_connectivity.npz
# Save file ../../data/chips/clean_data//12.bipartite.pkl
# finished building drive and net dict
# [0.005471956224350205]
# (15285, 1) [0.13319653]
# Save file ../../data/chips/clean_data//12.star.pkl
# Congestion info: ../../data/chips/NCSU-DigIC-GraphData-2023-07-25/xbar/13/xbar_congestion.npz
# Number of layers: 13
# Layers: ['M1', 'MINT1', 'MINT2', 'MINT3', 'MINT4', 'MINT5', 'MSMG1', 'MSMG2', 'MSMG3', 'MSMG4', 'MSMG5', 'MG1', 'MG2']
# Layer M1 :
# Time for binned statistics: 0.0009922981262207031
# Time to get demand and capacity: 0.002904176712036133
#     Number of demand > capacity: 4
#     Average capacity - demand: 0.027947464874770924
#     Average demand: 0.012522907758094075
#     Average capacity: 0.040470372632864994
# Layer MINT1 :
# Time for binned statistics: 0.0009987354278564453
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 1315
#     Average capacity - demand: 1.3824068417837507
#     Average demand: 9.388515577275504
#     Average capacity: 10.770922419059255
# Layer MINT2 :
# Time for binned statistics: 0.0020003318786621094
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 5779
#     Average capacity - demand: -3.1434025656689064
#     Average demand: 13.094838118509468
#     Average capacity: 9.951435552840563
# Layer MINT3 :
# Time for binned statistics: 0.0010170936584472656
# Time to get demand and capacity: 0.0010039806365966797
#     Number of demand > capacity: 1290
#     Average capacity - demand: 1.7264813683567501
#     Average demand: 10.026878436163715
#     Average capacity: 11.753359804520464
# Layer MINT4 :
# Time for binned statistics: 0.0010018348693847656
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 9.935094685400122
#     Average demand: 0.020616982284667074
#     Average capacity: 9.95571166768479
# Layer MINT5 :
# Time for binned statistics: 0.002000570297241211
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG1 :
# Time for binned statistics: 0.001007080078125
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG2 :
# Time for binned statistics: 0.001989603042602539
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG3 :
# Time for binned statistics: 0.001514434814453125
# Time to get demand and capacity: 0.0010135173797607422
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG4 :
# Time for binned statistics: 0.002001047134399414
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MSMG5 :
# Time for binned statistics: 0.0010066032409667969
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG1 :
# Time for binned statistics: 0.002001047134399414
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Layer MG2 :
# Time for binned statistics: 0.0010068416595458984
# Time to get demand and capacity: 0.0
#     Number of demand > capacity: 0
#     Average capacity - demand: 0.0
#     Average demand: 0.0
#     Average capacity: 0.0
# Save file ../../data/chips/clean_data//12.targets.pkl
